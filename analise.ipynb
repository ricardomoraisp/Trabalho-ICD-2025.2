# %%
# %pip install pandas sns matplotlib -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
arquivo = 'quantidade_ano.csv'
df = pd.read_csv(arquivo)
df
# Out:
#     data  quantidade
# 0   1968        3208
# 1   1965        1158
# 2   1962         585
# 3   1964         546
# 4   1961         435
# ..   ...         ...
# 92  1980           2
# 93  1918           1
# 94  1913           1
# 95  1916           1
# 96  1983           1
#
# [97 rows x 2 columns]

# %%
sns.lineplot(df, x='data', y='quantidade')
# Out:
# <Axes: xlabel='data', ylabel='quantidade'>
